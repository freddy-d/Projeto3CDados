# %% [markdown]
# Neste Notebook o dataset dos vistos disponível na internet, pelo link abaixo, e que contem mais de 3 milhões de linhas é modificado para um novo dataset.
#
# https://www.kaggle.com/nsharan/h-1b-visa

# %%
import pandas as pd
import numpy as np
import random
from pandas import ExcelWriter
from sklearn.model_selection import train_test_split

# %% [markdown]
# Na célula abaixo, o dataset é importado e após isso as linhas são embaralhadas.

# %%
dataset = pd.read_csv("h1b.csv")
dataset = dataset.sample(frac=0.3).reset_index(drop=True)
dataset.head()
# Out:
#    Unnamed: 0 CASE_STATUS                 EMPLOYER_NAME  \
# 0     1238015   CERTIFIED  FIS MANAGEMENT SERVICES, LLC
# 1     1648002   CERTIFIED               INFOSYS LIMITED
# 2     1439706   CERTIFIED      ONWARD TECHNOLOGIES, INC
# 3     2342831   CERTIFIED        OPTECH CONSULTING INC.
# 4     1564190   CERTIFIED   INFOSMART TECHNOLOGIES, INC
#
#                             SOC_NAME                       JOB_TITLE  \
# 0            DATABASE ADMINISTRATORS  DATABASE ADMINISTRATOR, SENIOR
# 1          Computer Systems Analysts       ASSOCIATE CONSULTANT - US
# 2               Computer Programmers             COMPUTER PROGRAMMER
# 3  Software Developers, Applications              PROGRAMMER ANALYST
# 4               Computer Programmers                   IT CONSULTANT
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR  \
# 0                  Y          93517.0  2015.0
# 1                  Y          49338.0  2014.0
# 2                  Y          58344.0  2014.0
# 3                  Y          83762.0  2012.0
# 4                  Y          52229.0  2014.0
#
#                            WORKSITE        lon        lat
# 0             BROWN DEER, WISCONSIN        NaN        NaN
# 1             KANSAS CITY, MISSOURI -94.578567  39.099727
# 2             NATICK, MASSACHUSETTS -71.346809  42.277528
# 3  WASHINGTON, DISTRICT OF COLUMBIA -77.036871  38.907192
# 4                  SUWANEE, GEORGIA -84.071300  34.051490

# %% [markdown]
# Na célula seguinte a um tratamento de dados. Todas as linhas na qual o resultado é WITHDRAWN, são retiradas do dataset, isso pois ele não cai em numa categoria que queira ser estudada, e também pois o processo não foi terminado. As duas linas de código seguintas também retiram linhas do dataset, pelo mesmo motivo a cima, o processo de aplicação para o visto de trabalho não foi terminado. Logo após isso as variavés são transformadas em 0 ou 1, para quando aprovado ou reprovado (CERTIFIED OU DENIED). Vale ressaltar que o caso CERTIFIED-WITHDRAWN, significa que a pessoa foi aprovada mas não quis terminar o processo para obter o visto, esse caso foi considerado como aprovado para o nosso estudo. Por último todas linhas qua não haviam uma das colunas completas, são removidas.

# %%
dataset = dataset[dataset.CASE_STATUS != "WITHDRAWN"]
dataset = dataset[dataset.CASE_STATUS != "PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED"]
dataset = dataset[dataset.CASE_STATUS != "INVALIDATED"]

dataset["CASE_STATUS"] = dataset["CASE_STATUS"].apply(lambda x: 1 if (x=="CERTIFIED-WITHDRAWN" or x=="CERTIFIED") else 0)

dataset = dataset.dropna()
dataset.head()
# Out:
#    Unnamed: 0  CASE_STATUS                                    EMPLOYER_NAME  \
# 1     1648002            1                                  INFOSYS LIMITED
# 2     1439706            1                         ONWARD TECHNOLOGIES, INC
# 3     2342831            1                           OPTECH CONSULTING INC.
# 4     1564190            1                      INFOSMART TECHNOLOGIES, INC
# 5      645585            1  COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION
#
#                             SOC_NAME  \
# 1          Computer Systems Analysts
# 2               Computer Programmers
# 3  Software Developers, Applications
# 4               Computer Programmers
# 5                    SALES ENGINEERS
#
#                                   JOB_TITLE FULL_TIME_POSITION  \
# 1                 ASSOCIATE CONSULTANT - US                  Y
# 2                       COMPUTER PROGRAMMER                  Y
# 3                        PROGRAMMER ANALYST                  Y
# 4                             IT CONSULTANT                  Y
# 5  ASSOCIATE DIRECTOR JC40 - SALES ENGINEER                  Y
#
#    PREVAILING_WAGE    YEAR                          WORKSITE        lon  \
# 1          49338.0  2014.0             KANSAS CITY, MISSOURI -94.578567
# 2          58344.0  2014.0             NATICK, MASSACHUSETTS -71.346809
# 3          83762.0  2012.0  WASHINGTON, DISTRICT OF COLUMBIA -77.036871
# 4          52229.0  2014.0                  SUWANEE, GEORGIA -84.071300
# 5         148824.0  2016.0                     IRVING, TEXAS -96.948894
#
#          lat
# 1  39.099727
# 2  42.277528
# 3  38.907192
# 4  34.051490
# 5  32.814018

# %% [markdown]
# Abaixo o novos datasets são criados a partir da aprovação ou reprovação no visto e depois são cortados na linha 50000. Por fim esse dois novos dataset são concatenados em um outro, o qual é exportado para um arquivo csv

# %%
# na = dataset[dataset["CASE_STATUS"] == 0]
# ap = dataset[dataset["CASE_STATUS"] == 1]

# na_cut = na[:10000]
# ap_cut = ap[:10000]

# df = pd.concat([ap_cut, na_cut])
# df = df.sample(frac=1).reset_index(drop=True)

treina,teste = train_test_split(dataset, test_size=0.2)
df.head()
# Out:
#    Unnamed: 0  CASE_STATUS                      EMPLOYER_NAME  \
# 0      353010            1              HYADES TECHNOLOGY INC
# 1     1679744            0  AXIOM SOFTWARE LABOARATORIES, INC
# 2     2065634            0         OLLER EXECUTIVE GROUP INC.
# 3      490742            1               SUNPOWER CORPORATION
# 4     1160570            0           BELUGA NORTH AMERICA INC
#
#                                     SOC_NAME                        JOB_TITLE  \
# 0          SOFTWARE DEVELOPERS, APPLICATIONS               SOFTWARE DEVELOPER
# 1           Financial Specialists, All Other  REGULATORY REPORTING SPECIALIST
# 2                   Accountants and Auditors                       ACCOUNTANT
# 3            COMPUTER OCCUPATIONS, ALL OTHER                  PROJECT MANAGER
# 4  PUBLIC RELATIONS AND FUNDRAISING MANAGERS         PUBLIC RELATIONS MANAGER
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                      WORKSITE  \
# 0                  Y          76107.0  2016.0      REDWOOD CITY, CALIFORNIA
# 1                  Y          81640.0  2014.0            NEW YORK, NEW YORK
# 2                  Y          55000.0  2013.0  JAMAICA PLAIN, MASSACHUSETTS
# 3                  N          52790.0  2016.0                 AUSTIN, TEXAS
# 4                  Y          92456.0  2015.0    NORTH MIAMI BEACH, FLORIDA
#
#           lon        lat
# 0 -122.236355  37.485215
# 1  -74.005941  40.712784
# 2  -71.115143  42.309736
# 3  -97.743061  30.267153
# 4  -80.162546  25.933149

# %%
df.to_csv("Dataframe.csv")
