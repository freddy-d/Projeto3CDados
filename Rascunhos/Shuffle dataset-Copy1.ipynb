# %% [markdown]
# Neste Notebook o dataset dos vistos disponível na internet, pelo link abaixo, e que contem mais de 3 milhões de linhas é modificado para um novo dataset.
#
# https://www.kaggle.com/nsharan/h-1b-visa

# %%
import pandas as pd
import numpy as np
import random
from pandas import ExcelWriter

# %% [markdown]
# Na célula abaixo, o dataset é importado e após isso as linhas são embaralhadas.

# %%
dataset = pd.read_csv("h1b.csv")
dataset = dataset.sample(frac=1).reset_index(drop=True)
dataset.head()
# Out:
#    Unnamed: 0 CASE_STATUS                            EMPLOYER_NAME  \
# 0     2065073   CERTIFIED        SKANSKA USA CIVIL NORTHWEST, INC.
# 1     2664504   CERTIFIED        TATA CONSULTANCY SERVICES LIMITED
# 2      329227   CERTIFIED                        SQUARETRADE, INC.
# 3     1562850   CERTIFIED                     TBC FALLS CHURCH LLC
# 4     2938235   CERTIFIED  SAMSUNG TELECOMMUNICATIONS AMERICA, LLC
#
#                                             SOC_NAME  \
# 0                                    Civil Engineers
# 1                               Computer Programmers
# 2                  SOFTWARE DEVELOPERS, APPLICATIONS
# 3  Market Research Analysts and Marketing Special...
# 4                  Software Developers, Applications
#
#                          JOB_TITLE FULL_TIME_POSITION  PREVAILING_WAGE  \
# 0          SENIOR PROJECT ENGINEER                  Y          84448.0
# 1              COMPUTER PROGRAMMER                  Y          61714.0
# 2                SOFTWARE ENGINEER                  Y         117603.0
# 3          MARKET RESEARCH ANALYST                  N          41496.0
# 4  SENIOR STAFF ENGINEER (MANAGER)                  Y          91312.0
#
#      YEAR                   WORKSITE         lon        lat
# 0  2013.0        SEATTLE, WASHINGTON -122.332071  47.606209
# 1  2011.0      JACKSONVILLE, FLORIDA  -81.655651  30.332184
# 2  2016.0  SAN FRANCISCO, CALIFORNIA -122.419415  37.774929
# 3  2014.0     FALLS CHURCH, VIRGINIA  -77.171091  38.882334
# 4  2011.0    BRIDGEWATER, NEW JERSEY  -74.604906  40.593964

# %% [markdown]
# Na célula seguinte a um tratamento de dados. Todas as linhas na qual o resultado é WITHDRAWN, são retiradas do dataset, isso pois ele não cai em numa categoria que queira ser estudada, e também pois o processo não foi terminado. As duas linas de código seguintas também retiram linhas do dataset, pelo mesmo motivo a cima, o processo de aplicação para o visto de trabalho não foi terminado. Logo após isso as variavés são transformadas em 0 ou 1, para quando aprovado ou reprovado (CERTIFIED OU DENIED). Vale ressaltar que o caso CERTIFIED-WITHDRAWN, significa que a pessoa foi aprovada mas não quis terminar o processo para obter o visto, esse caso foi considerado como aprovado para o nosso estudo. Por último todas linhas qua não haviam uma das colunas completas, são removidas.

# %%
dataset = dataset[dataset.CASE_STATUS != "WITHDRAWN"]
dataset = dataset[dataset.CASE_STATUS != "PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED"]
dataset = dataset[dataset.CASE_STATUS != "INVALIDATED"]

dataset["CASE_STATUS"] = dataset["CASE_STATUS"].apply(lambda x: 1 if (x=="CERTIFIED-WITHDRAWN" or x=="CERTIFIED") else 0)

dataset = dataset.dropna()
dataset.head()
# Out:
#    Unnamed: 0  CASE_STATUS                            EMPLOYER_NAME  \
# 0     2065073            1        SKANSKA USA CIVIL NORTHWEST, INC.
# 1     2664504            1        TATA CONSULTANCY SERVICES LIMITED
# 2      329227            1                        SQUARETRADE, INC.
# 3     1562850            1                     TBC FALLS CHURCH LLC
# 4     2938235            1  SAMSUNG TELECOMMUNICATIONS AMERICA, LLC
#
#                                             SOC_NAME  \
# 0                                    Civil Engineers
# 1                               Computer Programmers
# 2                  SOFTWARE DEVELOPERS, APPLICATIONS
# 3  Market Research Analysts and Marketing Special...
# 4                  Software Developers, Applications
#
#                          JOB_TITLE FULL_TIME_POSITION  PREVAILING_WAGE  \
# 0          SENIOR PROJECT ENGINEER                  Y          84448.0
# 1              COMPUTER PROGRAMMER                  Y          61714.0
# 2                SOFTWARE ENGINEER                  Y         117603.0
# 3          MARKET RESEARCH ANALYST                  N          41496.0
# 4  SENIOR STAFF ENGINEER (MANAGER)                  Y          91312.0
#
#      YEAR                   WORKSITE         lon        lat
# 0  2013.0        SEATTLE, WASHINGTON -122.332071  47.606209
# 1  2011.0      JACKSONVILLE, FLORIDA  -81.655651  30.332184
# 2  2016.0  SAN FRANCISCO, CALIFORNIA -122.419415  37.774929
# 3  2014.0     FALLS CHURCH, VIRGINIA  -77.171091  38.882334
# 4  2011.0    BRIDGEWATER, NEW JERSEY  -74.604906  40.593964

# %% [markdown]
# Abaixo o dataset é exportado para um arquivo csv

# %%
print(len(dataset))
dataset.head()
# Out:
# 2792997
#    Unnamed: 0  CASE_STATUS                            EMPLOYER_NAME  \
# 0     2065073            1        SKANSKA USA CIVIL NORTHWEST, INC.
# 1     2664504            1        TATA CONSULTANCY SERVICES LIMITED
# 2      329227            1                        SQUARETRADE, INC.
# 3     1562850            1                     TBC FALLS CHURCH LLC
# 4     2938235            1  SAMSUNG TELECOMMUNICATIONS AMERICA, LLC
#
#                                             SOC_NAME  \
# 0                                    Civil Engineers
# 1                               Computer Programmers
# 2                  SOFTWARE DEVELOPERS, APPLICATIONS
# 3  Market Research Analysts and Marketing Special...
# 4                  Software Developers, Applications
#
#                          JOB_TITLE FULL_TIME_POSITION  PREVAILING_WAGE  \
# 0          SENIOR PROJECT ENGINEER                  Y          84448.0
# 1              COMPUTER PROGRAMMER                  Y          61714.0
# 2                SOFTWARE ENGINEER                  Y         117603.0
# 3          MARKET RESEARCH ANALYST                  N          41496.0
# 4  SENIOR STAFF ENGINEER (MANAGER)                  Y          91312.0
#
#      YEAR                   WORKSITE         lon        lat
# 0  2013.0        SEATTLE, WASHINGTON -122.332071  47.606209
# 1  2011.0      JACKSONVILLE, FLORIDA  -81.655651  30.332184
# 2  2016.0  SAN FRANCISCO, CALIFORNIA -122.419415  37.774929
# 3  2014.0     FALLS CHURCH, VIRGINIA  -77.171091  38.882334
# 4  2011.0    BRIDGEWATER, NEW JERSEY  -74.604906  40.593964

# %%
na = dataset[dataset["CASE_STATUS"] == 0]
ap = dataset[dataset["CASE_STATUS"] == 1]

size=5000

na_cut = na[:size]
ap_cut = ap[:size]

df = pd.concat([ap_cut, na_cut])
df = df.sample(frac=1).reset_index(drop=True)
# df["CASE_STATUS"][df["CASE_STATUS"]==0].size
df.head()
# Out:
#    Unnamed: 0  CASE_STATUS                      EMPLOYER_NAME  \
# 0     2692228            0                  FLORIOGRAPHY, LLC
# 1     1772788            1                   MINDTREE LIMITED
# 2     2488118            1                    INFOSYS LIMITED
# 3     1463659            1  TATA CONSULTANCY SERVICES LIMITED
# 4     1448818            1    AMERICAN IT RESOURCE GROUP, INC
#
#                             SOC_NAME                JOB_TITLE  \
# 0           Market Research Analysts  MARKET RESEARCH ANALYST
# 1    Computer Occupations, All Other             TEST MANAGER
# 2          Computer Systems Analysts              MODULE LEAD
# 3               Computer Programmers      COMPUTER PROGRAMMER
# 4  Software Developers, Applications        SOFTWARE ENGINEER
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR               WORKSITE  \
# 0                  Y          40456.0  2011.0            KATY, TEXAS
# 1                  Y          63357.0  2014.0    FRANKLIN, TENNESSEE
# 2                  Y          39166.0  2012.0      ROANOKE, VIRGINIA
# 3                  Y          63690.0  2014.0  SAN DIEGO, CALIFORNIA
# 4                  Y          62712.0  2014.0   SCHAUMBURG, ILLINOIS
#
#           lon        lat
# 0  -95.824396  29.785785
# 1  -86.868890  35.925064
# 2  -79.941427  37.270970
# 3 -117.161084  32.715738
# 4  -88.083406  42.033361

# %%
df.to_csv("Dataframe2.csv")
