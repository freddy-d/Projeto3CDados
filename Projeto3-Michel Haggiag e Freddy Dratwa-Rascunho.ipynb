# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Dataframe.xlsx')
df.head()
# Out:
#        Unnamed: 0          CASE_STATUS  \
# 38779      172175            CERTIFIED
# 527       2578116            CERTIFIED
# 26502     2154116  CERTIFIED-WITHDRAWN
# 8041       248595            CERTIFIED
# 132        660347  CERTIFIED-WITHDRAWN
#
#                                     EMPLOYER_NAME  \
# 38779                V-SOFT CONSULTING GROUP, INC
# 527             XAVIENT INFORMATION SYSTEMS, INC.
# 26502                 WESTERNGECO RESOURCES, INC.
# 8041               NITHYA INFORMATION SYSTEMS INC
# 132    UNIVERSITY OF MASSACHUSETTS MEDICAL SCHOOL
#
#                                                 SOC_NAME  \
# 38779                          COMPUTER SYSTEMS ANALYSTS
# 527            Computer and Information Systems Managers
# 26502  Geoscientists, Except Hydrologists and Geograp...
# 8041                                COMPUTER PROGRAMMERS
# 132                               BIOLOGICAL TECHNICIANS
#
# ...

# %%
resultado = df.loc[:, ['CASE_STATUS']].dropna()
resultado.head()
# Out:
#                CASE_STATUS
# 38779            CERTIFIED
# 527              CERTIFIED
# 26502  CERTIFIED-WITHDRAWN
# 8041             CERTIFIED
# 132    CERTIFIED-WITHDRAWN

# %%
profissao = df.loc[:, ['JOB_TITLE']].dropna()
profissao.head()
# Out:
#                                           JOB_TITLE
# 38779                              BUSINESS ANALYST
# 527    ONSITE COORDINATOR (APPLICATION DEVELOPMENT)
# 26502                                  GEOPHYSICIST
# 8041           SENIOR COMPUTER PROGRAMMER\\ANALYSTS
# 132                CLINICAL RESEARCH COORDINATOR II

# %%
tempo = df.loc[:, ['FULL_TIME_POSITION']].dropna()
tempo.head()
# Out:
#       FULL_TIME_POSITION
# 38779                  N
# 527                    Y
# 26502                  Y
# 8041                   N
# 132                    Y

# %%
salario = df.loc[:, ['PREVAILING_WAGE']].dropna()
salario.head()
# Out:
#        PREVAILING_WAGE
# 38779          68453.0
# 527            76939.0
# 26502          78042.0
# 8041           63482.0
# 132            42432.0

# %%
R_P = resultado.join(profissao, how='inner')
R_P.head()
# Out:
#                CASE_STATUS                                     JOB_TITLE
# 38779            CERTIFIED                              BUSINESS ANALYST
# 527              CERTIFIED  ONSITE COORDINATOR (APPLICATION DEVELOPMENT)
# 26502  CERTIFIED-WITHDRAWN                                  GEOPHYSICIST
# 8041             CERTIFIED          SENIOR COMPUTER PROGRAMMER\\ANALYSTS
# 132    CERTIFIED-WITHDRAWN              CLINICAL RESEARCH COORDINATOR II

# %%
R_T = resultado.join(tempo, how='inner')
R_T.head()
# Out:
#                CASE_STATUS FULL_TIME_POSITION
# 38779            CERTIFIED                  N
# 527              CERTIFIED                  Y
# 26502  CERTIFIED-WITHDRAWN                  Y
# 8041             CERTIFIED                  N
# 132    CERTIFIED-WITHDRAWN                  Y

# %%
R_S = resultado.join(salario, how='inner')
R_S.head()
# Out:
#                CASE_STATUS  PREVAILING_WAGE
# 38779            CERTIFIED          68453.0
# 527              CERTIFIED          76939.0
# 26502  CERTIFIED-WITHDRAWN          78042.0
# 8041             CERTIFIED          63482.0
# 132    CERTIFIED-WITHDRAWN          42432.0
